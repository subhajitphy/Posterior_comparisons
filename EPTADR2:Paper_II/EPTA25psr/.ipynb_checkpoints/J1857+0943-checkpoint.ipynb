# %%
psrname='J1857+0943'

# %%
script_dir='/media/root1/3PAR/sdandapat/WORK/work_dir2'
work_dir='/media/root1/3PAR/sdandapat/'

# %%
spna_dir=work_dir+'posteriors/EPTA-ONLY/SPNA/'+psrname+'/'
spnta_dir=work_dir+'posteriors/EPTA-ONLY/SPNTA/'+psrname+'/results/'

# %%
import os
with os.scandir(spna_dir) as entries:
        for entry in entries:
            spna_dir=spna_dir+entry.name+'/ptmcmc/'

# %%
# %matplotlib inline
import sys, os
sys.path.insert(0,os.path.realpath(os.path.join(os.getcwd(),'../..')))
from getdist import plots, MCSamples
from getdist.gaussian_mixtures import GaussianND
import getdist
getdist.chains.print_load_details = False
import scipy
import matplotlib.pyplot as plt
import IPython
from IPython.display import Markdown
import numpy as np
import seaborn as sns
# import the tensiometer tools that we need:
import tensiometer
from tensiometer import utilities
from tensiometer import gaussian_tension
from tensiometer import mcmc_tension
import pandas as pd
sys.path.append(script_dir)
from diff_chain import  Diff_chain_shift
# Out:
# 2023-04-14 23:32:37.980808: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-14 23:32:38.026872: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-14 23:32:38.027883: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-14 23:32:38.745592: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
par_epta_spna=pd.read_csv(spna_dir+'pars.txt', header = None)
lspn=len(par_epta_spna)
par_epta_spna
# Out:
#                                           0
# 0             J1857+0943_EFF.EBPP.1360_efac
# 1    J1857+0943_EFF.EBPP.1360_log10_tnequad
# 2             J1857+0943_EFF.EBPP.1410_efac
# 3    J1857+0943_EFF.EBPP.1410_log10_tnequad
# 4             J1857+0943_EFF.EBPP.2639_efac
# 5    J1857+0943_EFF.EBPP.2639_log10_tnequad
# 6             J1857+0943_EFF.P200.1380_efac
# 7    J1857+0943_EFF.P200.1380_log10_tnequad
# 8             J1857+0943_EFF.P217.1380_efac
# 9    J1857+0943_EFF.P217.1380_log10_tnequad
# 10            J1857+0943_EFF.S110.2487_efac
# 11   J1857+0943_EFF.S110.2487_log10_tnequad
# 12             J1857+0943_EFF.S60.4857_efac
# 13    J1857+0943_EFF.S60.4857_log10_tnequad
# 14             J1857+0943_JBO.DFB.1520_efac
# 15    J1857+0943_JBO.DFB.1520_log10_tnequad
# 16           J1857+0943_JBO.ROACH.1520_efac
# 17  J1857+0943_JBO.ROACH.1520_log10_tnequad
# 18                J1857+0943_LEAP.1396_efac
# 19       J1857+0943_LEAP.1396_log10_tnequad
# 20             J1857+0943_NRT.BON.1400_efac
# 21    J1857+0943_NRT.BON.1400_log10_tnequad
# 22             J1857+0943_NRT.BON.1600_efac
# 23    J1857+0943_NRT.BON.1600_log10_tnequad
# 24             J1857+0943_NRT.BON.2000_efac
# 25    J1857+0943_NRT.BON.2000_log10_tnequad
# 26           J1857+0943_NRT.NUPPI.1484_efac
# 27  J1857+0943_NRT.NUPPI.1484_log10_tnequad
# 28           J1857+0943_NRT.NUPPI.2539_efac
# 29  J1857+0943_NRT.NUPPI.2539_log10_tnequad
# 30             J1857+0943_WSRT.P1.1380_efac
# 31    J1857+0943_WSRT.P1.1380_log10_tnequad
# 32             J1857+0943_WSRT.P2.1380_efac
# 33    J1857+0943_WSRT.P2.1380_log10_tnequad
# 34                   J1857+0943_dm_gp_gamma
# 35                 J1857+0943_dm_gp_log10_A

# %%
epta_spna_1=np.loadtxt(spna_dir+'chain_1.txt',usecols=(lspn-1,lspn-2,-3))

# %%
par_epta_spnta=pd.read_csv(spnta_dir+'TNfinal-'+psrname+'-.paramnames', header = None)
lspnt=len(par_epta_spnta)
par_epta_spnta
# Out:
#                    0
# 0         RAJ \alpha
# 1        DECJ \delta
# 2             F0 \nu
# 3       F1 \dot{\nu}
# 4                DM
# 5               DM1
# 6               DM2
# 7    PMRA \mu_\alpha
# 8   PMDEC \mu_\delta
# 9             PX \pi
# 10       SINI \sin i
# 11            PB P_b
# 12             A1 A1
# 13      TASC T_{asc}
# 14       EPS1 \kappa
# 15         EPS2 \eta
# 16            M2 m_2
# 17             EFAC1
# 18             EFAC2
# 19             EFAC3
# 20             EFAC4
# 21             EFAC5
# 22             EFAC6
# 23             EFAC7
# 24             EFAC8
# 25             EFAC9
# 26            EFAC10
# 27            EFAC11
# 28            EFAC12
# 29            EFAC13
# 30            EFAC14
# 31            EFAC15
# 32            EFAC16
# 33            EFAC17
# 34            EQUAD1
# 35            EQUAD2
# 36            EQUAD3
# 37            EQUAD4
# 38            EQUAD5
# 39            EQUAD6
# 40            EQUAD7
# 41            EQUAD8
# 42            EQUAD9
# 43           EQUAD10
# 44           EQUAD11
# 45           EQUAD12
# 46           EQUAD13
# 47           EQUAD14
# 48           EQUAD15
# 49           EQUAD16
# 50           EQUAD17
# 51             DMAmp
# 52           DMSlope

# %%
epta_spnta_1=np.loadtxt(spnta_dir+'TNfinal-'+psrname+'-post_equal_weights.dat',usecols=(lspnt-2,lspnt-1,-1))

# %%
epta_spna_1.T[0]=epta_spna_1.T[0]+1.64

# %%
spna_arr_dm=epta_spna_1.T[0:2];spnta_arr_dm=epta_spnta_1.T[0:2]

# %%
loglike_spna=epta_spna_1.T[-1];loglike_spnta=epta_spnta_1.T[-1]

# %% [markdown]
# # Tension considering dm noise only

# %%
names_dm = ['gamma_DM','logA_DM']
labels_dm=['\gamma_{DM}','\log A_{DM}']
del_dm=['delta_gamma_DM','delta_logA_DM']

# %%
spna_dm=MCSamples(samples=np.array(spna_arr_dm).transpose(),loglikes=loglike_spna,names=names_dm,labels=labels_dm,label='SPNA')
spnta_dm=MCSamples(samples=np.array(spnta_arr_dm).transpose(),loglikes=loglike_spnta,names = names_dm,labels=labels_dm,label='SPNTA \n'+psrname)

# %%
# %matplotlib inline
g = plots.get_subplot_plotter()
g.triangle_plot([spna_dm,spnta_dm], filled=True)
plt.savefig(psrname+'_R_DM_EPTA_dm.png',dpi=300)
plt.show()

# %%
# %matplotlib inline
diff_chain_dm, nsig_dm, chi_2_dm, D_B_dm=Diff_chain_shift(spna_dm,spnta_dm)
g = plots.get_subplot_plotter()
#nsig=utilities.from_confidence_to_sigma(shift_probability)
#getdist.plots.GetDistPlotSettings()
g.triangle_plot(diff_chain_dm, filled=True,legend_labels = [psrname+'\n\n$\Delta_T=$'+
                        str("{:.4f}".format(nsig_dm))+'$\sigma$'],markers=[0,0,0,0])
#g.add_label(['$\Delta=$'+str("{:.2f}".format(nsig))+'$\sigma$'], colodm_text=True)
plt.savefig(psrname+'_diff_EPTA_dm.png',dpi=300)

# %%
def plot_diff_chain(A1,A2,lims=None):
    diff_chain, nsig, shift_lower, shift_upper=Diff_chain_shift(A1,A2)
    
    shift_probability=utilities.from_sigma_to_confidence(nsig)
    g = plots.get_single_plotter()
    diff_chain.updateSettings({'contours': [shift_probability,0.68, 0.95]})
    g.settings.num_plot_contours = 3
    g.plot_2d(diff_chain,param1=del_dm[0], param2=del_dm[1], solid_colors='r',filled=True,lims=lims)
    g.add_legend([ A1.getLabel()+' vs '+A2.getLabel()+ 
                  '\n\n $\Delta=$'+str("{:.3f}".format(nsig))+'$\sigma$'], colored_text=True);
    g.add_x_marker(0)
    g.add_y_marker(0)
    #plt.savefig('diff_'+psrname+A1.getLabel()+'_'+A2.getLabel()+'.png',dpi=300)
    
    return diff_chain,shift_probability

# %%
plot_diff_chain(spna_dm,spnta_dm)
# Out:
# (<getdist.mcsamples.MCSamples at 0x7f5520616100>, 0.18259129564782392)
